# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>BIOS 4150/BIOL 6150</h1>
#     <h3>Instructor: Dr. King Jordan</h3>
#     <p>Nilavrah Sensarma (nsensarma3@gatech.edu),</p>
#     <p>Lasya Pasumarthy (vpasumarthy3@gatech.edu)</p>
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2>Project 1 (Data access & QC) starter notebook</h2>
#     <h3>Deadline: 11:59PM, September 22nd, 2025</h3>
# </div>

# %% [markdown]
# ### Rerun the analysis as demonstrated in the lab sessions

# %% [markdown]
# ---

# %% [markdown]
# # **1. Your assigned 1000 Genomes individual**
# ### *Total Questions: 3*
# ### *Total Points: 2+2+3 = 7*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.1 Does you group have an assigned individual ID from the 1000 Genomes Project?</h3>
#     <p>Find the individual on the international genomes website and paste a screenshot below</p>
# </div>

# %% [markdown]
# ## Our individual ID is NA21092

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.2 What population does you assigned individual belong to?</h3>
#     <p>Write about where the geographical location of where this individual lived at the time of recruitment? </p>
# </div>

# %%
#Write about the individual and their ancestors here.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.3 More about your individual's population?</h3>
#     <p>Read more about this population and write about their recent historical  (100-500 years) ancestors.</p>
# </div>

# %%
#Write about the individual and their ancestors here.

# %% [markdown]
# # **2. Exome sequencing**
# ### *Total Questions: 2*
# ### *Total Points: 3.5+3.5 = 7*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.1 Does your assigned individual has exome sequencing data? If yes, then what is the SRR ID for that sequencing run?</h3>
#     <p>Does you individual have multiple SRR IDs? In case they do, which one would you pick? (Hint: The sequencing information is coming from the same individual; but larger file size might be more preferable)</p>
# </div>

# %% [markdown]
# Our individual has two SSR IDs:
#
#     - SRR360498
#     - SRR360505

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.2 Looking at just the exome sequencing of this individual, how many variants would you expect them to carry compared to the reference genome?</h3>
#     <p>Keep in mind this is 1 individual, and learn about the expected number of variants from WGS, WES, and Genotyping</p>
# </div>

# %%
#Write about variant information here.

# %% [markdown]
# # **3. Data access**
# ### *Total Questions: 2*
# ### *Total Points: 3.5+3.5 = 7*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>3.1 Download the exome sequencing data for this individual and write the size of the files</h3>
#     <p>3.1.1 How many files do you have? Is the sequencing paired?</p>
#     <p>3.1.2 How many reads are present in each file? </p>
# </div>

# %%
#Show your download command and ls the directory.
#First Sequence: SRR360498
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360498_1.filt.fastq.gz
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360498_2.filt.fastq.gz

#Second Sequence: SRR360505
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360505_1.filt.fastq.gz
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360505_2.filt.fastq.gz
# Out:
# --2026-09-25 12:06:53--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360505_1.filt.fastq.gz
#            => ‘SRR360505_1.filt.fastq.gz’
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/ftp/phase3/data/NA21092/sequence_read ... done.
# ==> SIZE SRR360505_1.filt.fastq.gz ... 2607695599
# ==> PASV ... done.    ==> RETR SRR360505_1.filt.fastq.gz ... done.
# Length: 2607695599 (2.4G) (unauthoritative)
#
# SRR360505_1.filt.fa 100%[===================>]   2.43G  1.15MB/s    in 28m 42s
#
# 2026-09-25 12:35:36 (1.44 MB/s) - ‘SRR360505_1.filt.fastq.gz’ saved [2607695599]
#
# --2026-09-25 12:35:36--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA21092/sequence_read/SRR360505_2.filt.fastq.gz
# ...

# %%
#Copy files to shared environment
# !mkdir -p ~/biol6150/SharedEnvironment/group4/project1data
# !cp SRR360498_1.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/
# !cp SRR360498_2.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/
# !cp SRR360505_1.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/
# !cp SRR360505_2.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/

# %%
#Show moved files
# !ls -sh ~/biol6150/SharedEnvironment/group4/project1data/
# Out:
# total 11G
# 2.5G SRR360498_1.filt.fastq.gz	   0 Trimming
# 2.7G SRR360498_2.filt.fastq.gz	   0 fastQCAfterTrimming
# 2.5G SRR360505_1.filt.fastq.gz	   0 fastQCBeforeTrimming
# 2.7G SRR360505_2.filt.fastq.gz

# %%
#Write about the fastq file here.
#These commands will output the number of reads in each sequence
#These take some time to run since the files are large
# !zcat ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_1.filt.fastq.gz | grep @SRR | wc -l
# !zcat ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_2.filt.fastq.gz | grep @SRR | wc -l
# !zcat ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_1.filt.fastq.gz | grep @SRR | wc -l
# !zcat ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_2.filt.fastq.gz | grep @SRR | wc -l
# Out:
# /home/hice1/jrust8/biol6150/SharedEnvironment/group4/project1data/SRR360498_1.filt.fastq.gz:	 69.1% -- replaced with stdout
# 31613192
# 31613192
# 31805408
# 31805408

# %%
#Write about the fastq file here.

# %% [markdown]
# # **4. Pre-QC with FastQC**
# ### *Total Questions: 3*
# ### *Total Points: 4+4+6 = 14*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.1 Show your exact command below.</h3>
# </div>

# %%
#Create directories for QC results.
# !mkdir -p ~/biol6150/SharedEnvironment/group4/project1data/fastQCBeforeTrimming
# !mkdir -p ~/biol6150/SharedEnvironment/group4/project1data/Trimming
# !mkdir -p ~/biol6150/SharedEnvironment/group4/project1data/fastQCAfterTrimming

# !ls -sh ~/biol6150/SharedEnvironment/group4/project1data/
# Out:
# total 11G
# 2.5G SRR360498_1.filt.fastq.gz	   0 Trimming
# 2.7G SRR360498_2.filt.fastq.gz	   0 fastQCAfterTrimming
# 2.5G SRR360505_1.filt.fastq.gz	   0 fastQCBeforeTrimming
# 2.7G SRR360505_2.filt.fastq.gz

# %%
#Run fastqc for SRR ID: SRR360498
# !fastqc -o ~/biol6150/SharedEnvironment/group4/project1data/fastQCBeforeTrimming/ ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_1.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_2.filt.fastq.gz

#Run fastqc for SRR ID: SRR360505
# !fastqc -o ~/biol6150/SharedEnvironment/group4/project1data/fastQCBeforeTrimming/ ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_1.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_2.filt.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of SRR360498_1.filt.fastq.gz
# Approx 5% complete for SRR360498_1.filt.fastq.gz
# Approx 10% complete for SRR360498_1.filt.fastq.gz
# Approx 15% complete for SRR360498_1.filt.fastq.gz
# Approx 20% complete for SRR360498_1.filt.fastq.gz
# Approx 25% complete for SRR360498_1.filt.fastq.gz
# Approx 30% complete for SRR360498_1.filt.fastq.gz
# Approx 35% complete for SRR360498_1.filt.fastq.gz
# Approx 40% complete for SRR360498_1.filt.fastq.gz
# Approx 45% complete for SRR360498_1.filt.fastq.gz
# Approx 50% complete for SRR360498_1.filt.fastq.gz
# Approx 55% complete for SRR360498_1.filt.fastq.gz
# Approx 60% complete for SRR360498_1.filt.fastq.gz
# Approx 65% complete for SRR360498_1.filt.fastq.gz
# Approx 70% complete for SRR360498_1.filt.fastq.gz
# Approx 75% complete for SRR360498_1.filt.fastq.gz
# Approx 80% complete for SRR360498_1.filt.fastq.gz
# Approx 85% complete for SRR360498_1.filt.fastq.gz
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.2 Show the <i>per base sequencing quality</i></h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# # Per Base Sequence Quality Forward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Per Base Sequence Quality Backward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Per Sequence Quality Forward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Per Sequence Quality Backward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.3 Show the <i>Per base sequence content</i></h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# # Per Base Sequence Content Forward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Per Base Sequence Content Backward:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **5. Trimming with fastp**
# ### *Total Questions: 3*
# ### *Total Points: 7+7+7 = 21*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.1 What was the tool and command you used?</h3>
#     <p>Write the tool name and exact command below</p>
# </div>

# %%
#fastp
# !fastp --help

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.2 How did you perform the trimming?</h3>
#     <p>Did you use dynamic built-in features or hard coded parameters?</p>
#     <p>Did you have to go back and repeat the trimming after run(s) for <b>postQC?</b></p>
# </div>

# %%
#Trimming:
#Sequence SRR360498
# !fastp -i ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_1.filt.fastq.gz -I ~/biol6150/SharedEnvironment/group4/project1data/SRR360498_2.filt.fastq.gz -o ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360498_1.Trimmed.filt.fastq.gz -O ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360498_2.Trimmed.filt.fastq.gz -f 12 -t 15

#Sequence SRR360505
# !fastp -i ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_1.filt.fastq.gz -I ~/biol6150/SharedEnvironment/group4/project1data/SRR360505_2.filt.fastq.gz -o ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360505_1.Trimmed.filt.fastq.gz -O ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360505_2.Trimmed.filt.fastq.gz -f 12 -t 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.3 What percentage of reads did you lose in the trimming process?</h3>
#     <p>5.3.1 Write the total number of reads before and after trimming</p>
#     <p>5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)</p>
#
# </div>

# %%
#Before trimming:
#After trimming:

# %% [markdown]
# # **6. Post-QC with FastQC**
# ### *Total Questions: 3*
# ### *Total Points: 4+6+4 = 14*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.1 Show your exact command(s) below.</h3>
# </div>

# %%
#Command here
# !fastqc -o ~/biol6150/SharedEnvironment/group4/project1data/fastQCAfterTrimming/ ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360498_1.Trimmed.filt.fastq.gz ~/biol6150/SharedEnvironment/group4/project1data/Trimming/SRR360498_1.Trimmed.filt.fastq.gz

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.2 Show <i>per base sequencing quality</h3>
#     <p>If the quality was falling below 20 for certain regions then trim it. Add a screenshot below</p>
# </div>

# %%
##Add image here for 6.1

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.3 Show the <i>Per base sequence content</i></h3>
#     <p>Ideally we shouldn't see adapters at the beginning of the reads in the fastq files. Add a screenshot below</p>
# </div>

# %%
##Add image here for 6.2

# %% [markdown]
# # **7. Comparative Analysis**
# ### *Total Questions: 3*
# ### *Total points: 15+13+2 = 30*
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>7.1 Rerun the above workflow using another tool of your choice</i></h3>
#     <p> Briefly explain why you chose the tool </p>
# </div>

# %% [markdown]
# <span style="color:red;"> Be sure to create your own environment if you want to install anything.</span>

# %%
#Commands here

# %%
#Write here

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>7.2 Compare the results obtained from the original tools used</i></h3>
# </div>

# %%
#Compare the tools

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>7.3 On a scale of 1-10, how much did you rely on AI for the project?</i></h3>
#     <p> (1 = not at all, 10 = heavily dependent) </p>
# </div>

# %%
#Answer here
